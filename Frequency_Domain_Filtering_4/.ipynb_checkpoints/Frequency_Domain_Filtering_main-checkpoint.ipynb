# %% [markdown]
# # 第四次课堂作业——频率
#
# **学号：**201983160037
#
# **姓名：**强盛周
#
# **班级：**19信计嵌入1班
#
# **邮箱：**qshengz@foxmail.com
#
# **课程名称：**数字图像处理II
#
# **授课教师：**陈允杰教授

# %% [markdown]
# # 一、作业要求
# 实现以下内容
# - 理想低通滤波器
# - 布特沃思低通滤波器
# - 高斯低通滤波器

# %% [markdown]
# # 二、理论介绍
# ## 1 理想低通滤波器
#
# ### 1.1 定义
# ![](https://img-blog.csdnimg.cn/2019090220323852.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# 说明：理想表明在半径为D0的圆内，所有频率无衰减的通过，而在圆外则完全被衰减，它是关于原点径向对称的，也就是说定义一个径向截面，然后旋转360°就可以得到一个理想低通滤波器
#
# ### 1.2 示例
# ![](https://img-blog.csdnimg.cn/20190902203319494.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# 移除不同比例的高频分量的结果
#
# ![](https://img-blog.csdnimg.cn/20190902203358584.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ### 1.3 计算给定不同的半径值所过滤掉的功率大小
# ![](https://img-blog.csdnimg.cn/20190902203523449.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ### 1.4 理想低通滤波器的振铃效应
# 观察下面三幅图，边缘处都有波纹一样的效果，称为“振铃”效应，举个例子，敲锣的时候，会有“翁翁翁”的响声一样 过滤掉的频率越多，振铃效应越明显
# ![](https://img-blog.csdnimg.cn/2019090220364598.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ![](https://img-blog.csdnimg.cn/20190902203703971.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# 说明：由于理想低通滤波器的频率域剖面图类似于盒状滤波器，因此其空间域滤波器有sinc函数形状，空间域的滤波可以用卷积表示。
#
# ![](https://img-blog.csdnimg.cn/201909022037326.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# 结论： sinc 函数的展开度与H(u，v)滤波函数的半径成反比，D0越大，sinc函数就会趋近于一个和图像卷积是根本不会发生模糊的冲击，低通滤波的目标是找到没有振铃或振铃效应很小的滤波器
#
# ## 2 布特沃斯低通滤波器[BLPF]
# ### 2.1 定义
# ![](https://img-blog.csdnimg.cn/20190902203836541.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ### 2.2 如何定义截止频率？
# 使$H(u，v)$下降为其最大值的某个百分比的点可以作为截止频率
#
# ### 2.3 振铃效应说明
# 说明： 巴特沃斯滤波器没有明显的截止频率，它是平滑过渡的，所以一阶情况下不会产生振铃效应 二阶也不会有明显的振铃效应，但是更高阶的振铃效应明显
# ![](https://img-blog.csdnimg.cn/2019090220400529.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ### 2.4 举例
# 不同截止频率对应的滤波结果
# ![](https://img-blog.csdnimg.cn/20190902204022696.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ## 3. 高斯低通滤波器
# ### 3.1 定义
# ![](https://img-blog.csdnimg.cn/20190902204059104.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ### 3.2 示例
# 不同截止频率对应的滤波结果如下所示
# ![](https://img-blog.csdnimg.cn/20190902204128185.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)
#
# ## 4 三种低通滤波的区别与联系
# ![](https://img-blog.csdnimg.cn/20190902204157831.png?x-oss-process=image/watermark,type_ZmFuZ3poZW5naGVpdGk,shadow_10,text_aHR0cHM6Ly9ibG9nLmNzZG4ubmV0L2ZlbmdzaGVuZ3dlaTM=,size_16,color_FFFFFF,t_70)

# %% [markdown]
# # 三、实验以及结果

# %% [markdown]
# ## 1. 导入库

# %%
# @Author: Alephant——QSZ
import numpy as np
import cv2
import imageio
import matplotlib.pyplot as plt
from math import sqrt
from mpl_toolkits.mplot3d import Axes3D

eps = np.finfo(float).eps

# %%
## 2 绘图

# %% [markdown]
# ## 2.1 绘制三维透视图

# %%
def drawPerspective(handleax,input_matrix,title=None,cmap = "gray"):
    handleax.set_title(title)
    handleax.set_zlabel('Z')  # 坐标轴
    handleax.set_ylabel('Y')
    handleax.set_xlabel('X')
    x,y = input_matrix.shape
    X = np.arange(0,x,1)
    Y = np.arange(0,y,1)
    # 由于图像x,y坐标和 meshigrid出来是互反的
    # 这里需要调转一下
    # 否则会出现mismatch的现象
    X,Y = np.meshgrid(Y, X)
    handleax.plot_surface(Y, X, input_matrix, cmap=cmap)
#     handleax.plot_wireframe(Y, X, input_matrix, cmap=cmap)

# %%
3.

# %%
# 获得指定大小的理想滤波器
def getIdealMask(mask_shape, filter_d0,hl_type):
    assert hl_type in ("lpf","hpf")
    rows,cols = mask_shape[0],mask_shape[1]
    crow = rows/2
    ccol = cols/2
    mask = np.zeros((rows,cols))
    for i in range(rows):
        for j in range(cols):
            dis = sqrt((i-crow)**2 + (j-ccol)**2)
            if hl_type == "lpf":
                if dis <= filter_d0:
                    mask[i,j] = 1
                else:
                    mask[i,j] = 0
            elif hl_type == "hpf":
                if dis <= filter_d0:
                    mask[i,j] = 0
                else:
                    mask[i,j] = 1
    return mask

# 测试ILPF
# 参数设置
mask_shape = (100,100)
d = 20
filter_type = "lpf"
# 获得滤波器
myfilter = getIdealMask(mask_shape,d,filter_type)
# 绘图
plt.figure(figsize=(12,12))
ax1=plt.subplot(221,projection = "3d")
ax2=plt.subplot(222)
ax3=plt.subplot(223)
ax4=plt.subplot(224)
drawPerspective(ax1,myfilter,title = "ILPF Perspective Axes3D", cmap = "gray")
# 不想进行列表解析,需要调用frompyfunc构建np可以用的分段函数
ufunc1 = np.frompyfunc(lambda x: 0 if (x-d)>0 else 1, 1, 1)
drawCurv(ax2,[ufunc1],["ILPF"],d,title = "ILPF Curv")
drawPanel(ax3,myfilter,title = "ILPF Frequency Panel Axes2D")
spatial_myfilter = frequencyToSpatial(myfilter)
drawPanel(ax4,spatial_myfilter,title = "ILPF Spatial Panel Axes2D")
plt.show()

# 测试IHPF
d = 20
filter_type = "hpf"
myfilter = getIdealMask(mask_shape,d,filter_type)
plt.figure(figsize=(12,12))
ax1=plt.subplot(221,projection = "3d")
ax2=plt.subplot(222)
ax3=plt.subplot(223)
ax4=plt.subplot(224)
drawPerspective(ax1,myfilter,title = "IHPF Perspective Axes3D", cmap = "gray")
# 不想进行列表解析,需要调用frompyfunc构建np可以用的分段函数
ufunc1 = np.frompyfunc(lambda x: 1 if (x-d)>0 else 0, 1, 1)
drawCurv(ax2,[ufunc1],["IHPF"],d,title = "Curv")
drawPanel(ax3,myfilter,title = "IHPF Frequency Panel Axes2D")
spatial_myfilter = frequencyToSpatial(myfilter)
drawPanel(ax4,spatial_myfilter,title = "IHPF Spatial Panel Axes2D")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <module>
#      34 ax3=plt.subplot(223)
#      35 ax4=plt.subplot(224)
# ---> 36 drawPerspective(ax1,myfilter,title = "ILPF Perspective Axes3D", cmap = "gray")
#      37 # 不想进行列表解析,需要调用frompyfunc构建np可以用的分段函数
#      38 ufunc1 = np.frompyfunc(lambda x: 0 if (x-d)>0 else 1, 1, 1)
#
# NameError: name 'drawPerspective' is not defined

# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # 四、参考资料
